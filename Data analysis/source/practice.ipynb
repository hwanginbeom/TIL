# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\ad0486\anaconda3\lib\site-packages (4.50.2)

# %%
from tqdm import trange
from tqdm import tqdm

# %%
# f = open("CriteoSearchData", 'r')
f = open("CriteoSearchData", 'r')
lines = f.readlines()

# %%
train_date=[]
test_date=[]
count = 0 
for i in trange(0,1000000):
    train_date.append(lines[i].split('\t'))
for i in trange(1000000,1500000):
    test_date.append(lines[i].split('\t'))
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 1000000/1000000 [00:06<00:00, 163539.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 500000/500000 [00:02<00:00, 187727.32it/s]

# %%
train_date = pd.DataFrame(train_date)
test_date = pd.DataFrame(test_date)

# %%
train_date.columns=['Sale' , 'SalesAmountInEuro' ,'Time_delay_for_conversion' ,'click_timestamp','nb_clicks_1week','product_price','product_age_group','device_type','audience_id','product_gender','product_brand','product_category_1','product_category_2','product_category_3','product_category_4','product_category_5','product_category_6','product_category_7','product_country','product_id','product_title','partner_id','user_id']

# %%
train_date
# Out:
#        Sale SalesAmountInEuro Time_delay_for_conversion click_timestamp  \
# 0         0                -1                        -1      1598891820
# 1         0                -1                        -1      1598925284
# 2         0                -1                        -1      1598892568
# 3         0                -1                        -1      1598891174
# 4         0                -1                        -1      1598905245
# ...     ...               ...                       ...             ...
# 999995    1             55.52                      1689      1597179878
# 999996    0                -1                        -1      1597203004
# 999997    1             102.0                       692      1597205953
# 999998    0                -1                        -1      1597164316
# 999999    0                -1                        -1      1597201490
#
#        nb_clicks_1week product_price                 product_age_group  \
# 0                   -1           0.0                                -1
# 1                    0           0.0  4C90FD52FC53D2C1C205844CB69575AB
# 2                   -1           0.0                                -1
# 3                   -1           0.0                                -1
# 4                   -1           0.0                                -1
# ...                ...           ...                               ...
# 999995             114         27.51                                -1
# 999996              -1           0.0                                -1
# 999997              -1         100.0                                -1
# 999998              -1           0.0                                -1
# 999999              55           0.0                                -1
#
#                              device_type                       audience_id  \
# 0       7E56C27BFF0305E788DA55A029EC4988                                -1
# 1       D7D1FB49049702BF6338894757E0D959                                -1
# 2       7E56C27BFF0305E788DA55A029EC4988                                -1
# 3       D7D1FB49049702BF6338894757E0D959  B0E6BD3ACC0707BAB31CA2C2B08E652F
# 4       7E56C27BFF0305E788DA55A029EC4988                                -1
# ...                                  ...                               ...
# 999995  7E56C27BFF0305E788DA55A029EC4988                                -1
# 999996  7E56C27BFF0305E788DA55A029EC4988                                -1
# 999997  7E56C27BFF0305E788DA55A029EC4988                                -1
# 999998  D7D1FB49049702BF6338894757E0D959  951795EB43464C86FB534742A58D99FB
# 999999  7E56C27BFF0305E788DA55A029EC4988  ACEBB1033A0E853C11470868111DCD10
#
#                           product_gender  ...  \
# 0                                     -1  ...
# 1       1B491180398E2F0390E6A588B3BCE291  ...
# 2                                     -1  ...
# 3                                     -1  ...
# 4                                     -1  ...
# ...                                  ...  ...
# 999995                                -1  ...
# 999996                                -1  ...
# 999997                                -1  ...
# 999998                                -1  ...
# 999999                                -1  ...
#
#                       product_category_3                product_category_4  \
# 0                                     -1                                -1
# 1                                     -1                                -1
# 2                                     -1                                -1
# 3                                     -1                                -1
# 4                                     -1                                -1
# ...                                  ...                               ...
# 999995  A499E9AAE46A39789A2EB2C7F844B9EC                                -1
# 999996                                -1                                -1
# 999997                                -1                                -1
# 999998  BCCC1BBBA27989E192D26A0DA25E448E  130539907160BE09230361DD99EF9B38
# 999999  58D6D0E7760308F75E5FA67E03740C1E                                -1
#
#        product_category_5 product_category_6 product_category_7  \
# 0                      -1                 -1                 -1
# 1                      -1                 -1                 -1
# 2                      -1                 -1                 -1
# 3                      -1                 -1                 -1
# 4                      -1                 -1                 -1
# ...                   ...                ...                ...
# 999995                 -1                 -1                 -1
# 999996                 -1                 -1                 -1
# 999997                 -1                 -1                 -1
# 999998                 -1                 -1                 -1
# 999999                 -1                 -1                 -1
#
#                          product_country                        product_id  \
# 0       57A1D462A03BD076E029CF9310C11FC5  A66DB02AC1726A8D79C518B7F7AB79F0
# 1       57A1D462A03BD076E029CF9310C11FC5  4C6C62203B4CE5AA6DFCF17F2604DC37
# 2                                     -1                                -1
# 3                                     -1                                -1
# 4       57A1D462A03BD076E029CF9310C11FC5  5F4AFF2693601C2EFFE9AF2C1ED4222E
# ...                                  ...                               ...
# 999995  57A1D462A03BD076E029CF9310C11FC5  A259A936D7273358BBCCE1440AF6011E
# 999996  57A1D462A03BD076E029CF9310C11FC5  0BA69ABC322BF4C153CA5A63507A5B94
# 999997  57A1D462A03BD076E029CF9310C11FC5  4E7A8170ACC66F43F6E21EA5426C459D
# 999998  57A1D462A03BD076E029CF9310C11FC5  E0E57033F529929E6618F80F551C162C
# 999999  57A1D462A03BD076E029CF9310C11FC5  39480DC91A29769DF2510AAA38A6EDC1
#
#                                             product_title  \
# 0                                                      -1
# 1       3CE3D1623D32FB2A901822910AF72A0B C83584C673752...
# 2                                                      -1
# 3                                                      -1
# 4                                                      -1
# ...                                                   ...
# 999995  A8DE3C5AEC68CD05E766D08A639F7663 AE003E6EFD15B...
# 999996                                                 -1
# 999997                                                 -1
# 999998
# 999999  C144C3DF2E109844D586BB69D500F7BF D5E1E9365F93B...
#
#                               partner_id                             user_id
# 0       E3DDEB04F8AFF944B11943BB57D2F620  493CFB4A87C50804C94C0CF76ABD19CD\n
# 1       BD01BAFAE73CF38C403978BBB458300C  D0EBCD4402172AE3AA6FD21FB77BDE84\n
# 2       C4D189327BD87FEB3BF896DA716C6995  E8A8BEA257B19574C36108D0F0CDADE5\n
# 3       440255DF62CFD36FBC0206828FC488E0  9703077BD18F430BD232A6F74931928E\n
# 4       E3DDEB04F8AFF944B11943BB57D2F620  703B8CFC8D65A67BDF96595CCF992D27\n
# ...                                  ...                                 ...
# 999995  E3DDEB04F8AFF944B11943BB57D2F620  EF782BEB11E2924308F4334F84700421\n
# 999996  E3DDEB04F8AFF944B11943BB57D2F620  30D8D764E5C80611CAA0CD0E9227359A\n
# 999997  E3DDEB04F8AFF944B11943BB57D2F620  3FF4E389EE4E8F05739EA9CE29987411\n
# 999998  1E497AFE8EF3848C96D69635B1225D21  1F32C8E3411A7DDADDD82219728D1867\n
# 999999  E3DDEB04F8AFF944B11943BB57D2F620  6F7F7B25C9C3905C94EA21D5C9FDB085\n
#
# [1000000 rows x 23 columns]
